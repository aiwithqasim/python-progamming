# %%
print("String..")
# Out:
# String..

# %% [markdown]
# ## Variables

# %%
name = "Qasim Hassan"
print(name)
# Out:
# Qasim Hassan

# %%
type(name)
# Out:
# str

# %%
id(name)
# Out:
# 2124415196464

# %% [markdown]
# #### Datatypes
# - Numbers --> `Integers` eg: 35
# - Decimal --> `float` eg: 35.5
# - Characters/Alphats --> `string` eg: "Qasim Hassan"
# - Binary 1/0 OR True/Flase --> `Booleans` eg: True/False

# %%
number = 5000 # creation of variable

# %%
print(number) # printing of variables
# Out:
# 5000

# %%
type(number) # check type of variable
# Out:
# int

# %%
id(number) # check address of avriable
# Out:
# 2124421538640

# %%
weight = 40.6

# %%
print(weight)
# Out:
# 40.6

# %%
type(weight)
# Out:
# float

# %%
id(weight)
# Out:
# 2124413571216

# %% [markdown]
# Apply all these steps on diffferen data types ( string, integer, float, bool)
#
# 1- creating a variable eg: variable_name = variable_value
# 2- printing that variable eg: print(variable_name)
# 3- check the type of variable eg: type(variable_name)
# 4- check the address of the variable eg: id(variable_name)

# %%
# variabl_name = varibale_value

boolean_var = True

# %%
print(boolean_var)
# Out:
# True

# %%
type(boolean_var) # type(variable_name)
# Out:
# bool

# %%
id(boolean_var) # give us address
# Out:
# 140725400750848

# %% [markdown]
# ## Operators
#
# - Addition +
# - Subtraction -
# - Multiplication *
# - Divide /
# - Power **

# %%
2+5
# Out:
# 7

# %%
5-3
# Out:
# 2

# %%
3*3
# Out:
# 9

# %%
20/5 # Note it down that divide give result in FLOAT
# Out:
# 4.0

# %%
2**3 # 2*2*2
# Out:
# 8

# %%
4**5 # 4*4*4*4*4
# Out:
# 1024

# %% [markdown]
# #### Assignment and Markdown guide

# %% [markdown]
# Q: Create a variable that holds a string value.
#
# - point 1
# - point 2
# - point 3
#
# 1. number1
# 2. number2
# 3. number3
#
# To save file press --> `CTRL+S`

# %%
str_variable = "Muhammad Ai Jinnah"
print(str_variable)
# Out:
# Muhammad Ai Jinnah

# %% [markdown]
# Q:  this is

# %% [markdown]
# ### Unfamilier Operator (1/18/2026)
#
# - Reminder/Modulus %
# - Floor  //

# %%
20/5
# Out:
# 4.0

# %%
# 3*6 = 18
# 3*7 = 21
20 % 3
# Out:
# 2

# %%
13%4
# Out:
# 1

# %%
# 13/4 => 3.25

13//4
# Out:
# 3

# %%
# 20/3 = 6.66

20//3
# Out:
# 6

# %%
26//5
# Out:
# 5

# %% [markdown]
# ## Expressions (BODMAS)

# %%
# = ((5*4) + (4-2))-5
# = (20 + 2) - 5
# = 22 - 5
# = 17
((5*4) + (4-2))-5
# Out:
# 17

# %%
((((4*2)+2)/5)*3) +1
# Out:
# 7.0

# %% [markdown]
# ### Naming Convention and Reserve Keywords
#
# - id
# - type
# - print
# - if, else, elif
#
# Rules:
# - Don't have number in start
# - Naming can't ahve spaces (tip: use underscore)
# - Can't use reserve keywords
#
# Tips:
# - Always keep the name meanining full and consice
#     - name = "Qasim" --> Good
#     - city = "Qasim" --> wrong
#     - My_name_is = "Qasim"

# %% [markdown]
# 1. CTRL+SHIFT+S take a screenshot
# 2. Goto any Markdown cell
# 3. CTRL+V to paste the image.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
var_name = "name"
num = 1

# %% [markdown]
# #### SHORT CUT KEYS
#
# - To run a cell SHIFT+ENTER.
#
# - To convert Python cell to Markdown ESC + M
# - To conver Makrfown to Python cell ESC + Y
#
# - To create cell below ESC + B
# - To Create cell above ESC + A
#
# - To Delete a cell ESC+DD (Dshould be two times)

# %% [markdown]
# ### Conditional Statements

# %% [markdown]
# - if internert_available --> Class will be conducted.
# - if no internet_available --> There will be no class.

# %%
internet = True

# %% [markdown]
# if <condition>:
#     <Body of if with SPACES>
# else:
#     <Body of else SPACES>

# %%
if internet:
    print("Class will be Conducted")
    print("Goto to Institute")
    print("Attended the calss")
else:
    print("There will be no class")
# Out:
# Class will be Conducted
# Goto to Institute
# Attended the calss

# %% [markdown]
# Q: Write a python code that check the age. If age is greater then 18 then eligible for CNIC else not elibigle

# %%
age = 19

if age > 18:
    print("You're eligible for CNIC")
else:
    print("Sorry, You're not Eligible")
# Out:
# You're eligible for CNIC

# %% [markdown]
# ### Conditional Operators
#
# - Greater then `>`
# - Less then `<`
# - Not equal to `!=`
# - Greater then and Equal to `>=`
# - Less then and Equal to `<=`
# - equals to `==`

# %%
5 > 2
# Out:
# True

# %%
3 < 7
# Out:
# True

# %%
5 != 6
# Out:
# True

# %%
5 == 5
# Out:
# True

# %%
40 >= 41
# Out:
# False
