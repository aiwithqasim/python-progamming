# %% [markdown]
# ## Conditional Statements
#
# - if internetavailable --> Class will be conducted
# - else --> Class will not be conducted
#
# SYNTAX:
#
# ```
# if <condition>:
#     <body of if>
# else:
#     <body of else>
# ```

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
internetAvailable = True #True/False
independenceDay = "No"

if independenceDay == "Yes" and internetAvailable:
    print("Independance day acitvity will be held")
elif internetAvailable:
    print("Class will be conducted")
else:
    print("Class/Activity will not be conducted")
# Out:
# Class will be conducted

# %% [markdown]
# A school has following rules for grading system:
# - Below 25 - F
# - 25 to 45 - E
# - 45 to 50 - D
# - 50 to 60 - C
# - 60 to 80 - B
# - Above 80 - A
#
# Ask user to enter marks and print the corresponding grade.

# %%
marks = 100

if marks > 80 and marks <=100: 
    print("Your Grade is A")
elif marks > 60 and marks <= 80:
    print("Your Grade is B")
elif marks > 50 and marks <= 60:
    print("Your Grade is C")
elif marks > 45 and marks <= 50:
    print("Your Grade is D")
elif marks > 25 and marks <= 45:
    print("Your Grade is E")
elif marks > 0 and marks <= 25:
     print("Your Grade is F")
else:
    print("Invalid Input")
# Out:
# Your Grade is A

# %% [markdown]
# Write a program to check whether a number entered by user is even or odd.

# %%
number = 456

if number % 2 == 0:
    print("even")
else:
    print("odd")
# Out:
# even

# %%
2 / 2 == 0
# Out:
# False

# %%
2 % 2 == 0
# Out:
# True

# %% [markdown]
# ## User input

# %%
number = input("Enter your number: ")

type(number)
# Out:
# str

# %%
number = int(input("Enter your number: "))

if number % 2 == 0:
    print("even")
else:
    print("odd")
# Out:
# even

# %%
var = int(input("Enter anything: "))

print(type(var))
print(var)
# Out:
# <class 'int'>
# 123

# %%
var = input("Enter anything: ")

print(type(var))
print(var)
# Out:
# <class 'str'>
# Qasim Hassan

# %% [markdown]
# ## Concatenation:

# %%
fname = "Qasim"
lname = "Hassan"

# %% [markdown]
# #### Method -1: Using + operator

# %%
fname + lname
# Out:
# 'QasimHassan'

# %%
fname + " " + lname
# Out:
# 'Qasim Hassan'

# %%
fname + str(marks)
# Out:
# 'Qasim90'

# %% [markdown]
# #### Method -2: using f string

# %%
fullname = f"{fname} {lname}"

# %%
fullname
# Out:
# 'Qasim Hassan'

# %%
marks = 90

# %%
f"Your marks are: {marks}"
# Out:
# 'Your marks are: 90'

# %% [markdown]
# NOTE:
# - For concatenation using `+` operator you have to `TYPE` cast.
# - For concatenation using `f""` you `don't` need to `TYPE` cast.
